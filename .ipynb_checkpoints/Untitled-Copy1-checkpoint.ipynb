# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import math
import numpy as np
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
films = pd.read_csv("movie_metadata.csv")

# %%
films.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
films.columns
# Out:
# Index([u'color', u'director_name', u'num_critic_for_reviews', u'duration',
#        u'director_facebook_likes', u'actor_3_facebook_likes', u'actor_2_name',
#        u'actor_1_facebook_likes', u'gross', u'genres', u'actor_1_name',
#        u'movie_title', u'num_voted_users', u'cast_total_facebook_likes',
#        u'actor_3_name', u'facenumber_in_poster', u'plot_keywords',
#        u'movie_imdb_link', u'num_user_for_reviews', u'language', u'country',
#        u'content_rating', u'budget', u'title_year', u'actor_2_facebook_likes',
#        u'imdb_score', u'aspect_ratio', u'movie_facebook_likes'],
#       dtype='object')

# %%
films["profit"] = (films["gross"] - films["budget"])

films.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
allGenres = ""
for g in films.genres:
    allGenres += "|"+g
genre_set = list(set(allGenres.split("|")))
genre_set
# Out:
# ['',
#  'Sci-Fi',
#  'Crime',
#  'Romance',
#  'Animation',
#  'Music',
#  'Comedy',
#  'War',
#  'Horror',
#  'Film-Noir',
#  'Adventure',
#  'News',
#  'Reality-TV',
#  'Thriller',
#  'Western',
#  'Mystery',
#  'Short',
#  'Drama',
#  'Action',
#  'Documentary',
#  'Musical',
#  'History',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'Sport',
#  'Biography']

# %%
for genre in genre_set:
    if genre != "":
        films[genre] = [genre in g for g in films["genres"]]
        
films.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
genre_set.remove('')

# %%
genreGrossTotalList = []

for genre in genre_set:
    genreTotalGross = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["gross"][index]):
            genreTotalGross += float(films["gross"][index])
    genreGrossTotalList.append([genre, genreTotalGross])
    
genreGrossTotalList
# Out:
# [['Sci-Fi', 41862249820.0],
#  ['Crime', 28274539845.0],
#  ['Romance', 39901610065.0],
#  ['Animation', 21818664778.0],
#  ['Music', 11683238115.0],
#  ['Comedy', 77437971840.0],
#  ['War', 6552231254.0],
#  ['Horror', 13793814984.0],
#  ['Film-Noir', 7927.0],
#  ['Adventure', 79806607293.0],
#  ['News', 14359793.0],
#  ['Reality-TV', 0.0],
#  ['Thriller', 54908859373.0],
#  ['Western', 2633546760.0],
#  ['Mystery', 18133701260.0],
#  ['Short', 7852534.0],
#  ['Drama', 73913303544.0],
#  ['Action', 75145540469.0],
#  ['Documentary', 1103051501.0],
#  ['Musical', 5846156663.0],
#  ['History', 5701332271.0],
#  ['Family', 42061385738.0],
#  ['Fantasy', 45116052975.0],
#  ['Game-Show', 0.0],
#  ['Sport', 6953941724.0],
#  ['Biography', 9005655093.0]]

# %%
genreGrossTotalListDataFrame = pd.DataFrame(genreGrossTotalList, columns=["Genre", "Total Earnings"])
genreGrossTotalListDataFrame.plot(kind="bar", x="Genre", y="Total Earnings", color=(0.8,0.2,0.2))

# %%
genreGrossAverageList = []

for genre in genre_set:
    genreTotalGross = 0.0
    filmGenreCount = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["gross"][index]):
            genreTotalGross += float(films["gross"][index])
            filmGenreCount += 1
    try:
        genreGrossAverageList.append([genre, genreTotalGross/filmGenreCount])
    except Exception:
        genreGrossAverageList.append([genre, 0])

genreGrossAverageList
# Out:
# [['Sci-Fi', 82244105.7367387],
#  ['Crime', 37154454.46123522],
#  ['Romance', 41825587.07023061],
#  ['Animation', 106954239.10784313],
#  ['Music', 41429922.39361702],
#  ['Comedy', 47683480.197044335],
#  ['War', 38317141.83625731],
#  ['Horror', 33561593.6350365],
#  ['Film-Noir', 7927.0],
#  ['Adventure', 98405187.78421701],
#  ['News', 14359793.0],
#  ['Reality-TV', 0],
#  ['Thriller', 46890571.625106744],
#  ['Western', 39306668.059701495],
#  ['Mystery', 44445346.2254902],
#  ['Short', 3926267.0],
#  ['Drama', 34538926.88971963],
#  ['Action', 76289888.80101523],
#  ['Documentary', 12121445.065934066],
#  ['Musical', 53146878.75454546],
#  ['History', 35193409.08024691],
#  ['Family', 89302305.1762208],
#  ['Fantasy', 85447070.0284091],
#  ['Game-Show', 0],
#  ['Sport', 41392510.26190476],
#  ['Biography', 34372729.36259542]]

# %%
genreGrossAverageListDataFrame = pd.DataFrame(genreGrossAverageList, columns=["Genre", "Average Earnings"])
genreGrossAverageListDataFrame.plot(kind="bar", x="Genre", y="Average Earnings",color=(0.8,0.2,0.2)
)

# %%
AverageBudgetList = []

for genre in genre_set:
    TotalBudget = 0.0
    filmGenreCount = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["budget"][index]):
            TotalBudget += float(films["budget"][index])
            filmGenreCount += 1
    try:
        AverageBudgetList.append([genre, TotalBudget/filmGenreCount])
    except Exception:
        AverageBudgetList.append([genre, 0])

AverageBudgetList
# Out:
# [['Sci-Fi', 86434003.98434782],
#  ['Crime', 34760181.92069393],
#  ['Romance', 31419191.209533267],
#  ['Animation', 97836098.19730942],
#  ['Music', 26486676.09090909],
#  ['Comedy', 38386977.1889483],
#  ['War', 53230506.61691542],
#  ['Horror', 41030898.957446806],
#  ['Film-Noir', 1556875.4],
#  ['Adventure', 79242669.24886878],
#  ['News', 1206500.0],
#  ['Reality-TV', 3000000.0],
#  ['Thriller', 38537686.87566743],
#  ['Western', 30193050.56043956],
#  ['Mystery', 32085542.301123597],
#  ['Short', 2015666.6666666667],
#  ['Drama', 35609817.44653813],
#  ['Action', 64476221.304268844],
#  ['Documentary', 4795310.831578948],
#  ['Musical', 35839647.655737706],
#  ['History', 41159647.84536082],
#  ['Family', 63564519.93503937],
#  ['Fantasy', 64562141.124125876],
#  ['Game-Show', 3000000.0],
#  ['Sport', 30769817.098765433],
#  ['Biography', 26485683.036764707]]

# %%
AverageBudgetListDataFrame = pd.DataFrame(AverageBudgetList, columns=["Genre", "Average Budget"])
AverageBudgetListDataFrame.plot(kind="bar", x="Genre", y="Average Budget", color=(0.8,0.8,0.2))

# %%
TotalProfitList = []

for genre in genre_set:
    TotalProfit = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["profit"][index]):
            TotalProfit += float(films["profit"][index])
    TotalProfitList.append([genre, TotalProfit])
    
TotalProfitList
# Out:
# [['Sci-Fi', -7382359889.0],
#  ['Crime', 636644497.0],
#  ['Romance', 8802850372.0],
#  ['Animation', 186871406.0],
#  ['Music', 3901466892.0],
#  ['Comedy', 12401933708.0],
#  ['War', -3715674734.0],
#  ['Horror', -7002206860.0],
#  ['Film-Noir', -2292073.0],
#  ['Adventure', 10754333579.0],
#  ['News', 0.0],
#  ['Reality-TV', 0.0],
#  ['Thriller', 5379318545.0],
#  ['Western', 29792856.0],
#  ['Mystery', 4017680245.0],
#  ['Short', 1818534.0],
#  ['Drama', -6209274298.0],
#  ['Action', 5166341649.0],
#  ['Documentary', 458205601.0],
#  ['Musical', 1438927340.0],
#  ['History', -1614348940.0],
#  ['Family', 9725838150.0],
#  ['Fantasy', 8739141427.0],
#  ['Game-Show', 0.0],
#  ['Sport', 1777598167.0],
#  ['Biography', 1924604134.0]]

# %%
TotalProfitListDataFrame = pd.DataFrame(TotalProfitList, columns=["Genre", "Total Profit"])
TotalProfitListDataFrame.plot(kind="bar", x="Genre", y="Total Profit", color=(0.9,0.5,0.15))

# %%
AverageProfitList = []

for genre in genre_set:
    TotalProfit = 0.0
    filmGenreCount = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["profit"][index]):
            TotalProfit += float(films["profit"][index])
            filmGenreCount += 1
    try:
        AverageProfitList.append([genre, TotalProfit/filmGenreCount])
    except Exception:
        AverageProfitList.append([genre, 0])

AverageProfitList
# Out:
# [['Sci-Fi', -14735249.279441118],
#  ['Crime', 884228.4680555556],
#  ['Romance', 9913119.788288288],
#  ['Animation', 939052.2914572865],
#  ['Music', 15605867.568],
#  ['Comedy', 8207765.524818001],
#  ['War', -22936263.790123455],
#  ['Horror', -17637800.65491184],
#  ['Film-Noir', -2292073.0],
#  ['Adventure', 13527463.621383648],
#  ['News', 0],
#  ['Reality-TV', 0],
#  ['Thriller', 4760458.889380531],
#  ['Western', 480529.93548387097],
#  ['Mystery', 10301744.217948718],
#  ['Short', 909267.0],
#  ['Drama', -3166381.5900050993],
#  ['Action', 5326125.411340206],
#  ['Documentary', 6838889.567164179],
#  ['Musical', 13970168.349514563],
#  ['History', -10348390.641025642],
#  ['Family', 21469841.390728477],
#  ['Fantasy', 16903561.75435203],
#  ['Game-Show', 0],
#  ['Sport', 11694724.782894736],
#  ['Biography', 7887721.860655738]]

# %%
AverageProfitListDataFrame = pd.DataFrame(AverageProfitList, columns=["Genre", "Average Profit"])
AverageProfitListDataFrame.plot(kind="bar", x="Genre", y="Average Profit", color=(0.9,0.5,0.15))

# %%
TimeStart = 1950

# %%
genreGrossTotalList_Time = []

for genre in genre_set:
    genreTotalGross = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["gross"][index]) and (TimeStart + 5) >= films["title_year"][index] >= TimeStart:
            genreTotalGross += float(films["gross"][index])
    genreGrossTotalList_Time.append([genre, genreTotalGross])
    
genreGrossTotalList_Time
# Out:
# [['Sci-Fi', 5000000.0],
#  ['Crime', 9600000.0],
#  ['Romance', 53600000.0],
#  ['Animation', 0.0],
#  ['Music', 8000000.0],
#  ['Comedy', 8000000.0],
#  ['War', 0.0],
#  ['Horror', 5000000.0],
#  ['Film-Noir', 0.0],
#  ['Adventure', 5269061.0],
#  ['News', 0.0],
#  ['Reality-TV', 0.0],
#  ['Thriller', 0.0],
#  ['Western', 8000000.0],
#  ['Mystery', 0.0],
#  ['Short', 0.0],
#  ['Drama', 81869061.0],
#  ['Action', 269061.0],
#  ['Documentary', 0.0],
#  ['Musical', 8000000.0],
#  ['History', 36000000.0],
#  ['Family', 36000000.0],
#  ['Fantasy', 0.0],
#  ['Game-Show', 0.0],
#  ['Sport', 0.0],
#  ['Biography', 8000000.0]]

# %%
genreGrossTotalList_TimeDataFrame = pd.DataFrame(genreGrossTotalList_Time, columns=["Genre", "Total Earnings"])
genreGrossTotalList_TimeDataFrame.plot(kind="bar", x="Genre", y="Total Earnings", color=(0.8,0.2,0.2)
)

# %%
genreGrossAverageList_Time = []

for genre in genre_set:
    genreTotalGross = 0.0
    filmGenreCount = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["gross"][index]) and (TimeStart + 5) >= films["title_year"][index] >= TimeStart:
            genreTotalGross += float(films["gross"][index])
            filmGenreCount += 1
    try:
        genreGrossAverageList_Time.append([genre, genreTotalGross/filmGenreCount])
    except Exception:
        genreGrossAverageList_Time.append([genre, 0])

genreGrossAverageList_Time
# Out:
# [['Sci-Fi', 5000000.0],
#  ['Crime', 9600000.0],
#  ['Romance', 17866666.666666668],
#  ['Animation', 0],
#  ['Music', 8000000.0],
#  ['Comedy', 8000000.0],
#  ['War', 0],
#  ['Horror', 5000000.0],
#  ['Film-Noir', 0],
#  ['Adventure', 2634530.5],
#  ['News', 0],
#  ['Reality-TV', 0],
#  ['Thriller', 0],
#  ['Western', 8000000.0],
#  ['Mystery', 0],
#  ['Short', 0],
#  ['Drama', 20467265.25],
#  ['Action', 269061.0],
#  ['Documentary', 0],
#  ['Musical', 8000000.0],
#  ['History', 36000000.0],
#  ['Family', 36000000.0],
#  ['Fantasy', 0],
#  ['Game-Show', 0],
#  ['Sport', 0],
#  ['Biography', 8000000.0]]

# %%
genreGrossAverageList_TimeDataFrame = pd.DataFrame(genreGrossAverageList_Time, columns=["Genre", "Average Earnings"])
genreGrossAverageList_TimeDataFrame.plot(kind="bar", x="Genre", y="Average Earnings", color=(0.8,0.2,0.2)
)

# %%
AverageBudgetList_Time = []

for genre in genre_set:
    genreTotalGross = 0.0
    filmGenreCount = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["budget"][index]) and (TimeStart + 5) >= films["title_year"][index] >= TimeStart:
            TotalBudget += float(films["budget"][index])
            filmGenreCount += 1
    try:
        AverageBudgetList_Time.append([genre, TotalBudget/filmGenreCount])
    except Exception:
        AverageBudgetList_Time.append([genre, 0])

AverageBudgetList_Time
# Out:
# [['Sci-Fi', 10471960262.0],
#  ['Crime', 15709020393.0],
#  ['Romance', 3930253600.0],
#  ['Animation', 0],
#  ['Music', 10483544604.666666],
#  ['Comedy', 10486047799.666666],
#  ['War', 31459793399.0],
#  ['Horror', 31460003399.0],
#  ['Film-Noir', 31461253399.0],
#  ['Adventure', 7868365849.75],
#  ['News', 0],
#  ['Reality-TV', 0],
#  ['Thriller', 15737731699.5],
#  ['Western', 15739991092.0],
#  ['Mystery', 31481182184.0],
#  ['Short', 0],
#  ['Drama', 2865587328.4545455],
#  ['Action', 31523460613.0],
#  ['Documentary', 0],
#  ['Musical', 10510688542.333334],
#  ['History', 10516562875.666666],
#  ['Family', 7891496014.0],
#  ['Fantasy', 15787992028.0],
#  ['Game-Show', 0],
#  ['Sport', 0],
#  ['Biography', 15793687920.5]]

# %%
AverageBudgetList_TimeDataFrame = pd.DataFrame(AverageBudgetList_Time, columns=["Genre", "Total Earnings"])
AverageBudgetList_TimeDataFrame.plot(kind="bar", x="Genre", y="Total Earnings", color=(0.8,0.8,0.2))

# %%
TotalProfitList_Time = []

for genre in genre_set:
    TotalProfit = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["profit"][index]) and (TimeStart + 5) >= films["title_year"][index] >= TimeStart:
            TotalProfit += float(films["profit"][index])
    TotalProfitList_Time.append([genre, TotalProfit])
    
TotalProfitList_Time
# Out:
# [['Sci-Fi', 4790000.0],
#  ['Crime', 8690000.0],
#  ['Romance', 44921215.0],
#  ['Animation', 0.0],
#  ['Music', 4231215.0],
#  ['Comedy', 4231215.0],
#  ['War', 0.0],
#  ['Horror', 4790000.0],
#  ['Film-Noir', 0.0],
#  ['Adventure', 3059061.0],
#  ['News', 0.0],
#  ['Reality-TV', 0.0],
#  ['Thriller', 0.0],
#  ['Western', 4231215.0],
#  ['Mystery', 0.0],
#  ['Short', 0.0],
#  ['Drama', 69959061.0],
#  ['Action', -1730939.0],
#  ['Documentary', 0.0],
#  ['Musical', 4231215.0],
#  ['History', 31000000.0],
#  ['Family', 32000000.0],
#  ['Fantasy', 0.0],
#  ['Game-Show', 0.0],
#  ['Sport', 0.0],
#  ['Biography', 4231215.0]]

# %%
TotalProfitList_TimeDataFrame = pd.DataFrame(TotalProfitList_Time, columns=["Genre", "Total Profit"])
TotalProfitList_TimeDataFrame.plot(kind="bar", x="Genre", y="Total Profit", color=(0.9,0.5,0.15))

# %%
AverageProfitList_Time = []

for genre in genre_set:
    TotalProfit = 0.0
    filmGenreCount = 0.0
    for index in range(len(films[genre])):
        if films[genre][index] and not math.isnan(films["profit"][index]) and (TimeStart + 5) >= films["title_year"][index] >= TimeStart:
            TotalProfit += float(films["profit"][index])
            filmGenreCount += 1
    try:
        AverageProfitList_Time.append([genre, TotalProfit/filmGenreCount])
    except Exception:
        AverageProfitList_Time.append([genre, 0])

AverageProfitList_Time
# Out:
# [['Sci-Fi', 4790000.0],
#  ['Crime', 8690000.0],
#  ['Romance', 14973738.333333334],
#  ['Animation', 0],
#  ['Music', 4231215.0],
#  ['Comedy', 4231215.0],
#  ['War', 0],
#  ['Horror', 4790000.0],
#  ['Film-Noir', 0],
#  ['Adventure', 1529530.5],
#  ['News', 0],
#  ['Reality-TV', 0],
#  ['Thriller', 0],
#  ['Western', 4231215.0],
#  ['Mystery', 0],
#  ['Short', 0],
#  ['Drama', 17489765.25],
#  ['Action', -1730939.0],
#  ['Documentary', 0],
#  ['Musical', 4231215.0],
#  ['History', 31000000.0],
#  ['Family', 32000000.0],
#  ['Fantasy', 0],
#  ['Game-Show', 0],
#  ['Sport', 0],
#  ['Biography', 4231215.0]]

# %%
AverageProfitListDataFrame_Time = pd.DataFrame(AverageProfitList_Time, columns=["Genre", "Average Profit"])
AverageProfitListDataFrame_Time.plot(kind="bar", x="Genre", y="Average Profit", color=(0.9,0.5,0.15))

# %%
genreCount = []

for combo in films["genres"]:
    splitGenres = combo.split("|")
    genreCount.extend(splitGenres)
    
genreCount
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Thriller',
#  'Documentary',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Romance',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Mystery',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Western',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Sci-Fi',
#  'Adventure',
#  'Fantasy',
#  'Action',
# ...

# %%
genreDataFrame = pd.DataFrame(genreCount, columns=["Genres"])
genreDataFrame
# Out:
#             Genres
# 0           Action
# 1        Adventure
# 2          Fantasy
# 3           Sci-Fi
# 4           Action
# 5        Adventure
# 6          Fantasy
# 7           Action
# 8        Adventure
# 9         Thriller
# 10          Action
# 11        Thriller
# 12     Documentary
# 13          Action
# 14       Adventure
# 15          Sci-Fi
# 16          Action
# 17       Adventure
# 18         Romance
# 19       Adventure
# 20       Animation
# 21          Comedy
# 22          Family
# 23         Fantasy
# 24         Musical
# 25         Romance
# 26          Action
# 27       Adventure
# 28          Sci-Fi
# 29       Adventure
# ...            ...
# 14474       Horror
# 14475     Thriller
# 14476        Crime
# 14477        Drama
# 14478        Drama
# 14479       Sci-Fi
# 14480     Thriller
# 14481     Thriller
# 14482       Action
# 14483        Crime
# 14484        Drama
# 14485      Romance
# 14486     Thriller
# 14487        Crime
# 14488        Drama
# ...

# %%
for genre in genre_set:
    if genre != "":
        films[films[genre]].duration.hist(alpha=0.5)
plt.ylabel("No. Films", fontsize=24)
plt.xlabel("Duration", fontsize=24)
plt.show()

# %%
for genre in genre_set:
    if genre != "":
        films[films[genre]].gross.hist(bins=200)
plt.ylabel("No. Films", fontsize=24)
plt.xlabel("Gross Earnings", fontsize=24)
plt.show()

# %%
for genre in genre_set:
    if genre != "":
        films[films[genre]].gross.hist(alpha=0.5)
plt.hist(films["Action"], range(0,1000), facecolor='green', alpha=0.75)
plt.xlabel('Number of Films')
plt.ylabel('Gross Earnings')
plt.title('Total Earnings per Genre')

plt.grid(True)
plt.show()

# %%
films.title_year.value_counts().plot(kind="bar")

# %%
genreDataFrame.Genres.value_counts().plot(kind="bar")

# %%
films.color.value_counts().plot(kind="bar")

# %%
fdnvc = films.director_name.value_counts()
fdnvc[fdnvc >= 10].plot(kind="bar")

# %%
films.content_rating.value_counts().plot(kind="bar")
